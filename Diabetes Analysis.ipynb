# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv(r'D:\csv files\diabetes.csv')

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Diabetes at 20 to 40 age

# %%
ab=dataset.loc[((dataset['Age']>20) & (dataset['Age']<=40)) & (dataset['Outcome']==1)]

# %%
ab
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 11            10      168             74              0        0  38.0
# 15             7      100              0              0        0  30.0
# ..           ...      ...            ...            ...      ...   ...
# 746            1      147             94             41        0  49.3
# 748            3      187             70             22      200  36.4
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
# 755            1      128             88             39      110  36.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %% [markdown]
# ### 166 peoples between 20 to 40 age have diabetes disease

# %%
ac=dataset.loc[((dataset['Age']>20) & (dataset['Age']<=40)) & (dataset['Outcome']==0)]

# %%
ac
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %% [markdown]
# ### 408 peoples between 20 to 40 age do not have diabetes disease

# %% [markdown]
# ### Diabetes at greater than 40 age

# %%
ad=dataset.loc[(dataset['Age']>40) & (dataset['Outcome']==1)]

# %%
ad
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### 102 peoples whose age is greater than 40 have diabetes disease

# %%
ae=dataset.loc[(dataset['Age']>40) & (dataset['Outcome']==0)]

# %%
ae
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 12            10      139             80              0        0  27.1
# 21             8       99             84              0        0  35.4
# 28            13      145             82             19      110  22.2
# 30             5      109             75             26        0  36.0
# 34            10      122             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 724            1      111             94              0        0  32.8
# 734            2      105             75              0        0  23.3
# 737            8       65             72             23        0  32.0
# 745           12      100             84             33      105  30.0
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 12                      1.441   57        0
# ...

# %% [markdown]
# ### 92 peoples whose age is greater than 40 do not have diabetes disease

# %%
sns.relplot(x='Age',y='Glucose',data=dataset,col='Outcome')
